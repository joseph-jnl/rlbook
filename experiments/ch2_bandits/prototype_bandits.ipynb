# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
import pandas as pd
import numpy as np
from rlbook.bandits.testbeds import NormalTestbed
from rlbook.bandits.bandits import EpsilonGreedy, init_constant

# %%
EXPECTED_VALUES = {
    1: {"mean": 2, "var": 1},
    2: {"mean": -1, "var": 1},
    3: {"mean": 1, "var": 1},
    4: {"mean": 0, "var": 1},
    5: {"mean": 1.7, "var": 1},
}

testbed = NormalTestbed(EXPECTED_VALUES)
testbed_drift = NormalTestbed(EXPECTED_VALUES, p_drift=0.0)

bandit = EpsilonGreedy(init_constant(testbed, q_val=10), epsilon=0)
bandit.run(testbed, 2000, n_runs=1)

# %%
bandit.output_df()
# Out:
#       run    step  action    reward  optimal_action  epsilon
# 0     0.0     0.0     2.0 -1.595949             1.0        0
# 1     0.0     1.0     5.0  3.269859             1.0        0
# 2     0.0     2.0     4.0 -0.212422             1.0        0
# 3     0.0     3.0     3.0  0.928148             1.0        0
# 4     0.0     4.0     1.0  1.439497             1.0        0
# ...   ...     ...     ...       ...             ...      ...
# 1995  0.0  1995.0     1.0  1.058638             1.0        0
# 1996  0.0  1996.0     1.0  1.972638             1.0        0
# 1997  0.0  1997.0     1.0  1.205776             1.0        0
# 1998  0.0  1998.0     1.0  1.556379             1.0        0
# 1999  0.0  1999.0     1.0  2.462039             1.0        0
#
# [2000 rows x 6 columns]
